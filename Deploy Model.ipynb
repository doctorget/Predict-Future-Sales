# %%
import pickle

# %%
modelo = pickle.load(open('arima_model.sav','rb'))

# %%
import pandas as pd

# %%
df = pd.read_csv('data_scaled.csv')
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
df = pd.read_csv('data_scaled.csv', parse_dates = ['mes'], index_col = 'mes', date_parser = dateparse)

# %%
df.head()
# Out:
#               vendas
# mes
# 2013-01-01  0.849691
# 2013-02-01  0.730595
# 2013-03-01  1.400119
# 2013-04-01 -0.003872
# 2013-05-01 -0.011603

# %%
df.dtypes
# Out:
# vendas    float64
# dtype: object

# %%
eixo = df.plot()
modelo.plot_predict('2015-10-01','2016-10-01', ax = eixo, plot_insample = True)
