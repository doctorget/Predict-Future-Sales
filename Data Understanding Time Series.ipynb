# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
dados = pd.read_csv('dados/sales_train.csv')

# %%
dados.head()
# Out:
#          data  mes_consecutivo  loja_id  item_id  preco_item  venda_item_dia
# 0  02.01.2013                0       59    22154      999.00             1.0
# 1  03.01.2013                0       25     2552      899.00             1.0
# 2  05.01.2013                0       25     2552      899.00            -1.0
# 3  06.01.2013                0       25     2554     1709.05             1.0
# 4  15.01.2013                0       25     2555     1099.00             1.0

# %%
dados.mes_consecutivo.plot(kind='hist')

# %%
dados.isna().sum()
# Out:
# data               0
# mes_consecutivo    0
# loja_id            0
# item_id            0
# preco_item         0
# venda_item_dia     0
# dtype: int64

# %%
dados.dtypes
# Out:
# data                object
# mes_consecutivo      int64
# loja_id              int64
# item_id              int64
# preco_item         float64
# venda_item_dia     float64
# dtype: object

# %%
dados['data'] = pd.to_datetime(dados['data'])

# %%
dados.dtypes
# Out:
# data               datetime64[ns]
# mes_consecutivo             int64
# loja_id                     int64
# item_id                     int64
# preco_item                float64
# venda_item_dia            float64
# dtype: object

# %%
import seaborn as sns

# %%
sns.lineplot(x='mes_consecutivo',y='venda_item_dia', data=dados)

# %%
sns.set_palette('Accent')
sns.set_style('darkgrid')
ax = sns.lineplot(x='mes_consecutivo',y='venda_item_dia', data=dados)
ax.figure.set_size_inches(12,6)
ax.set_title('Vendas janeiro de 2013 a outubro de 2015', loc='left')
# Out:
# Text(0.0, 1.0, 'Vendas janeiro de 2013 a outubro de 2015')
